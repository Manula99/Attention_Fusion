# %%
import medrs
import time

# %%
time_start = time.time()
img = medrs.load("/home/manula/277B_Project/monai_data/Task01_BrainTumour/labelsTr/BRATS_001.nii.gz")
time_end = time.time()
print(f"Loading time: {time_end - time_start} seconds")
# Out:
# Loading time: 0.013045072555541992 seconds

# %%
import monai

# %%
#test monai loading time
time_start = time.time()
img = monai.transforms.LoadImage(image_only=True)("/home/manula/277B_Project/monai_data/Task01_BrainTumour/labelsTr/BRATS_001.nii.gz")
time_end = time.time()
print(f"Monai loading time: {time_end - time_start} seconds")
# Out:
# Monai loading time: 0.06279134750366211 seconds

# %%
import nibabel

# %%
time_start = time.time()
img = nibabel.load("/home/manula/277B_Project/monai_data/Task01_BrainTumour/labelsTr/BRATS_001.nii.gz")
img_data = img.dataobj
print(img_data.shape)
time_end = time.time()
print(f"Nibabel loading time: {time_end - time_start} seconds")
# Out:
# (240, 240, 155)
# Nibabel loading time: 0.0012671947479248047 seconds
