# %%
from Attention_Fusion import distributed_trainer
from Attention_Fusion import U_Transformer
import os
os.environ['MONAI_DATA_DIRECTORY'] = '/content/monai_data'

# %%
model = U_Transformer(4, 3)

# %%
from accelerate import notebook_launcher

notebook_launcher(distributed_trainer, (model,), num_processes=2)
